# %%
# !nvidia-smi
# Out:
# Sat Dec 13 04:22:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
print("YOLO installed successfully")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLO installed successfully

# %%
import zipfile

with zipfile.ZipFile("annotated.zip", "r") as zip_ref:
    zip_ref.extractall("dataset")

# %%
# !ls dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !cat dataset/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 6
# names: ['Acropora', 'Damselfish', 'Encrusting Coral', 'Porites', 'coral', 'fish']
#
# roboflow:
#   workspace: dataset-qfj1e
#   project: my-first-project-1uq2b
#   version: 3
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/dataset-qfj1e/my-first-project-1uq2b/dataset/3

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # lightweight model

model.train(
    data="dataset/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# ...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 68.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
print("YOLO imported successfully")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLO imported successfully

# %%
# !ls
# Out:
# annotated.zip  drive  sample_data

# %%
import zipfile

with zipfile.ZipFile("annotated.zip", "r") as zip_ref:
    zip_ref.extractall("dataset")

# %%
# !ls dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="dataset/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# ...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
model = YOLO("runs/detect/train/weights/best.pt")

model.predict(
    source="dataset/test/images",
    conf=0.3,
    save=True
)
# Out:
# image 1/61 /content/dataset/test/images/input_mp4-0036_jpg.rf.0386179a092c1be98982549fd9261d60.jpg: 640x640 1 Damselfish, 8 Encrusting Corals, 1 coral, 1 fish, 7.9ms
# image 2/61 /content/dataset/test/images/input_mp4-0065_jpg.rf.cdf16a34855e7b0c571a5167772c3a01.jpg: 640x640 6 Encrusting Corals, 4 corals, 2 fishs, 7.3ms
# image 3/61 /content/dataset/test/images/input_mp4-0077_jpg.rf.58d6a82781e29a24a1ab0c7c7766e203.jpg: 640x640 6 Encrusting Corals, 3 corals, 4 fishs, 7.2ms
# image 4/61 /content/dataset/test/images/input_mp4-0083_jpg.rf.e8f5a8ff03fb85fd36f26b76c67d4833.jpg: 640x640 6 Encrusting Corals, 2 corals, 4 fishs, 7.2ms
# image 5/61 /content/dataset/test/images/input_mp4-0095_jpg.rf.fa97d3bfb76f3dab3e598c56c6c5ceca.jpg: 640x640 6 Encrusting Corals, 2 corals, 5 fishs, 7.2ms
# image 6/61 /content/dataset/test/images/input_mp4-0107_jpg.rf.f48522c89352da97eaddb72926628c40.jpg: 640x640 6 Encrusting Corals, 4 corals, 8 fishs, 7.2ms
# ...

# %%
from google.colab import files
files.download("runs/detect/train/weights/best.pt")

# %%
# !ls
# Out:
# annotated.zip  dataset	drive  runs  sample_data  yolo11n.pt  yolov8n.pt

# %%
# !ls
# Out:
# drive  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
files.upload()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from google.colab import files
files.upload()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !mv input1.mp4 /content/drive/MyDrive/
# !mv best.pt /content/drive/MyDrive/

# %%
# !ls /content/drive/MyDrive/
# Out:
#  best.pt  'Colab Notebooks'   input1.mp4

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/"
# Out:
# Untitled0.ipynb

# %%
# !ls -lh "/content/drive/MyDrive/Colab Notebooks/"
# Out:
# total 344K
# -rw------- 1 root root 344K Dec 13 06:42 Untitled0.ipynb

# %%
# !find /content/drive/MyDrive -name "best.pt"
# Out:
# /content/drive/MyDrive/best.pt

# %%
# !find /content/drive/MyDrive -name "input1.mp4"
# Out:
# /content/drive/MyDrive/input1.mp4

# %%
model_path = "/content/drive/MyDrive/best.pt"
video_path = "/content/drive/MyDrive/input1.mp4"
output_path = "/content/drive/MyDrive/output_counted.mp4"

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.4 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
import cv2
from collections import defaultdict

model = YOLO("/content/drive/MyDrive/best.pt")

cap = cv2.VideoCapture("/content/drive/MyDrive/input1.mp4")
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

out = cv2.VideoWriter(
    "/content/drive/MyDrive/output_counted.mp4",
    cv2.VideoWriter_fourcc(*'mp4v'),
    fps,
    (w, h)
)

unique_ids = defaultdict(set)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model.track(
        frame,
        persist=True,
        tracker="bytetrack.yaml",
        conf=0.3,
        iou=0.5
    )

    if results[0].boxes.id is not None:
        for box, cls, tid in zip(
            results[0].boxes.xyxy,
            results[0].boxes.cls,
            results[0].boxes.id
        ):
            cls = int(cls)
            tid = int(tid)
            unique_ids[cls].add(tid)

            x1, y1, x2, y2 = map(int, box)
            cv2.rectangle(frame, (x1,y1), (x2,y2), (0,255,0), 2)
            cv2.putText(frame, f"ID {tid} | Class {cls}",
                        (x1, y1-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                        (0,255,0), 2)

    out.write(frame)

cap.release()
out.release()

print("FINAL COUNT:")
for cls, ids in unique_ids.items():
    print(f"Class {cls}: {len(ids)}")

print("Saved to /content/drive/MyDrive/output_counted.mp4")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 2 packages in 103ms
# Prepared 1 package in 17ms
# Installed 1 package in 3ms
#  + lap==0.5.12
#
# requirements: AutoUpdate success ✅ 0.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# 0: 384x640 8 Encrusting Corals, 2 corals, 2 fishs, 83.8ms
# Speed: 16.4ms preprocess, 83.8ms inference, 42.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Encrusting Corals, 2 corals, 1 fish, 6.7ms
# ...

# %%
# !pip install -U ultralytics

# %%
from ultralytics import YOLO
import cv2
from collections import defaultdict

# Load model
model = YOLO("/content/drive/MyDrive/best.pt")

# Class names (EDIT this!)
class_names = {
    0: "Fish",
    1: "Hard Coral",
    2: "Soft Coral",
    3: "Brain Coral",
    4: "Table Coral",
    5: "Branching Coral"
}

# Store unique IDs
unique_ids = defaultdict(set)

# Open video
video_path = "/content/drive/MyDrive/input1.mp4"
cap = cv2.VideoCapture(video_path)

# Output video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(
    "/content/drive/MyDrive/output_counted.mp4",
    fourcc,
    cap.get(cv2.CAP_PROP_FPS),
    (int(cap.get(3)), int(cap.get(4)))
)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model.track(
        frame,
        persist=True,
        tracker="bytetrack.yaml",
        conf=0.3
    )

    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        ids = results[0].boxes.id.cpu().numpy()
        classes = results[0].boxes.cls.cpu().numpy()

        for box, track_id, cls in zip(boxes, ids, classes):
            cls = int(cls)
            track_id = int(track_id)

            # Count unique objects
            unique_ids[cls].add(track_id)

            # Color rule
            if class_names[cls] == "Fish":
                color = (255, 0, 0)   # Blue
            else:
                color = (0, 0, 255)   # Red

            label = f"{class_names[cls]} ID:{track_id}"

            x1, y1, x2, y2 = map(int, box)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1-5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    out.write(frame)

cap.release()
out.release()

# Final counts
print("FINAL COUNT:")
for cls, ids in unique_ids.items():
    print(f"{class_names[cls]}: {len(ids)}")
# Out:
# 0: 384x640 9 Encrusting Corals, 2 corals, 2 fishs, 16.8ms
# Speed: 3.6ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 Encrusting Corals, 2 corals, 1 fish, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 Encrusting Corals, 1 coral, 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 Encrusting Corals, 1 coral, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 Encrusting Corals, 3 corals, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 Encrusting Corals, 3 corals, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Encrusting Corals, 3 corals, 6.5ms
# ...

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO
import cv2
from collections import defaultdict

# Load trained model
model = YOLO("/content/drive/MyDrive/best.pt")

# Class ID → Name mapping
class_names = {
    0: "Fish",
    1: "Hard Coral",
    2: "Soft Coral",
    3: "Brain Coral",
    4: "Table Coral",
    5: "Branching Coral"
}

# Store unique tracked IDs per class
unique_ids = defaultdict(set)

# Input video
video_path = "/content/drive/MyDrive/input1.mp4"
cap = cv2.VideoCapture(video_path)

# Check video open
assert cap.isOpened(), "❌ Input video not found or cannot be opened"

# Output video (NEW NAME → avoids overwrite issue)
output_path = "/content/drive/MyDrive/output_colored_counted.mp4"

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(
    output_path,
    fourcc,
    cap.get(cv2.CAP_PROP_FPS),
    (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
     int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
)

assert out.isOpened(), "❌ Output video writer failed"

# ---------- PROCESS VIDEO ----------
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model.track(
        frame,
        persist=True,
        tracker="bytetrack.yaml",
        conf=0.3
    )

    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        ids = results[0].boxes.id.cpu().numpy()
        classes = results[0].boxes.cls.cpu().numpy()

        for box, track_id, cls in zip(boxes, ids, classes):
            cls = int(cls)
            track_id = int(track_id)

            # Count unique objects
            unique_ids[cls].add(track_id)

            # ---------- COLOR LOGIC ----------
            if class_names[cls] == "Fish":
                color = (255, 0, 0)        # Blue (Fish)
            else:
                color = (0, 255, 0)        # Green (Coral)

            label = f"{class_names[cls]} | ID:{track_id}"

            x1, y1, x2, y2 = map(int, box)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 8),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    out.write(frame)

# Release resources
cap.release()
out.release()

# ---------- FINAL ORDERED COUNT ----------
print("\n✅ FINAL POPULATION COUNT\n---------------------------")
for cls in sorted(class_names.keys()):
    print(f"{class_names[cls]:15s}: {len(unique_ids[cls])}")

print(f"\n🎥 Output video saved at:\n{output_path}")
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 2 packages in 109ms
# Prepared 1 package in 18ms
# Installed 1 package in 3ms
#  + lap==0.5.12
#
# requirements: AutoUpdate success ✅ 0.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# 0: 384x640 9 Encrusting Corals, 2 corals, 2 fishs, 66.5ms
# Speed: 15.9ms preprocess, 66.5ms inference, 42.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 Encrusting Corals, 2 corals, 1 fish, 7.3ms
# Speed: 2.7ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 Encrusting Corals, 1 coral, 5.7ms
# Speed: 1.7ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 Encrusting Corals, 1 coral, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
# !gh repo clone Surendersahk/uwd
# Out:
# To get started with GitHub CLI, please run:  gh auth login
# Alternatively, populate the GH_TOKEN environment variable with a GitHub API authentication token.

# %%
# !git clone https://github.com/Surendersahk/uwd.git
# Out:
# Cloning into 'uwd'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !ls
# Out:
# drive  sample_data  uwd

# %%
# !mv drive sample_data uwd/
# Out:
# mv: cannot move 'drive' to 'uwd/drive': Device or resource busy

# %%
# !mv sample_data models results uwd/
# Out:
# mv: cannot stat 'sample_data': No such file or directory
# mv: cannot stat 'models': No such file or directory
# mv: cannot stat 'results': No such file or directory
